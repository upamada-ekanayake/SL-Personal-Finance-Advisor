# %% [markdown]
# <a href="https://colab.research.google.com/github/upamada-ekanayake/SL-Personal-Finance-Advisor/blob/main/Day3_4_Create_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd  # This is the tool we use to handle data

# 1. We create the data manually (A list of "dictionaries")
data = [
    # --- INCOME (Money Coming In) ---
    {"Date": "2024-01-01", "Category": "Income", "Description": "Monthly Salary", "Amount": 150000, "Type": "Income"},
    {"Date": "2024-01-15", "Category": "Income", "Description": "Freelance Project", "Amount": 25000, "Type": "Income"},

    # --- EXPENSES (Money Going Out) ---
    # Food & Groceries
    {"Date": "2024-01-02", "Category": "Food", "Description": "Keells Supermarket Grocery", "Amount": 12500, "Type": "Expense"},
    {"Date": "2024-01-03", "Category": "Food", "Description": "Rice Packet Lunch", "Amount": 450, "Type": "Expense"},
    {"Date": "2024-01-05", "Category": "Food", "Description": "Kottu Dinner (Hotel)", "Amount": 1200, "Type": "Expense"},
    {"Date": "2024-01-10", "Category": "Food", "Description": "Cargills Food City", "Amount": 5000, "Type": "Expense"},

    # Transport
    {"Date": "2024-01-02", "Category": "Transport", "Description": "Bus Ticket to Colombo", "Amount": 350, "Type": "Expense"},
    {"Date": "2024-01-04", "Category": "Transport", "Description": "PickMe Three-wheeler", "Amount": 450, "Type": "Expense"},
    {"Date": "2024-01-20", "Category": "Transport", "Description": "Uber Ride", "Amount": 1100, "Type": "Expense"},

    # Bills & Utilities
    {"Date": "2024-01-25", "Category": "Bills", "Description": "Dialog Mobile Bill", "Amount": 2100, "Type": "Expense"},
    {"Date": "2024-01-26", "Category": "Bills", "Description": "CEB Electricity Bill", "Amount": 4500, "Type": "Expense"},
    {"Date": "2024-01-27", "Category": "Bills", "Description": "Water Board Bill", "Amount": 800, "Type": "Expense"},

    # Housing
    {"Date": "2024-01-01", "Category": "Rent", "Description": "Boarding Fees", "Amount": 25000, "Type": "Expense"},

    # Personal / Shopping
    {"Date": "2024-01-12", "Category": "Shopping", "Description": "New Shirt (ODEL/Fashion Bug)", "Amount": 3500, "Type": "Expense"},
    {"Date": "2024-01-14", "Category": "Health", "Description": "Panadol & Vitamins", "Amount": 650, "Type": "Expense"},
]

# 2. Convert this list into a DataFrame (A Table)
df = pd.DataFrame(data)

# 3. Save it as a CSV file (This creates the file in your Colab folder)
df.to_csv("srilanka_finance_data.csv", index=False)

# 4. Show the first 5 rows to check if it worked
print("✅ Dataset created successfully!")
print("Here are the first few rows:")
print(df.head())
# Out:
# ✅ Dataset created successfully!
# Here are the first few rows:
#          Date Category                 Description  Amount     Type
# 0  2024-01-01   Income              Monthly Salary  150000   Income
# 1  2024-01-15   Income           Freelance Project   25000   Income
# 2  2024-01-02     Food  Keells Supermarket Grocery   12500  Expense
# 3  2024-01-03     Food           Rice Packet Lunch     450  Expense
# 4  2024-01-05     Food        Kottu Dinner (Hotel)    1200  Expense

# %%
from google.colab import files

# Download the file to your local computer to check it
files.download('srilanka_finance_data.csv')
